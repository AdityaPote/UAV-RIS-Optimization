# %%
# # Number of RIS elements for the extended analysis
# EXTENDED_NUMBER_OF_ELEMENTS = 300

# import numpy as np

# # Convert lists to NumPy arrays (assuming they were initially lists)
# extended_reflection_coefficients = np.array(extended_reflection_coefficients)
# extended_horizontal_channel_gains = np.array(extended_horizontal_channel_gains)
# extended_transmit_efficiency_factors = np.array(extended_transmit_efficiency_factors)
# extended_energy_harvested = np.array(extended_energy_harvested)
# extended_energy_transmitted = np.array(extended_energy_transmitted)
# extended_transmitted_snr_values = np.array(extended_transmitted_snr_values)

# # Sorting elements by transmitted SNR values in ascending order
# sorted_indices = np.argsort(extended_transmitted_snr_values)
# extended_reflection_coefficients = extended_reflection_coefficients[sorted_indices]
# extended_horizontal_channel_gains = extended_horizontal_channel_gains[sorted_indices]
# extended_transmit_efficiency_factors = extended_transmit_efficiency_factors[sorted_indices]
# extended_energy_harvested = extended_energy_harvested[sorted_indices]
# extended_energy_transmitted = extended_energy_transmitted[sorted_indices]
# extended_transmitted_snr_values = extended_transmitted_snr_values[sorted_indices]

# # Function to run the genetic algorithm for a specific number of elements and return the transmitted SNR
# def run_genetic_algorithm_for_elements(number_of_elements):
#     # Slicing the extended parameters for the given number of elements
#     reflection_coeffs = extended_reflection_coefficients[:number_of_elements]
#     horizontal_channel_gains = extended_horizontal_channel_gains[:number_of_elements]
#     transmit_efficiency_factors = extended_transmit_efficiency_factors[:number_of_elements]
#     energy_harvested = extended_energy_harvested[:number_of_elements]
#     energy_transmitted = extended_energy_transmitted[:number_of_elements]
#     transmitted_snr_values = extended_transmitted_snr_values[:number_of_elements]

#     # Creating the initial population for the given number of elements
#     initial_population = create_initial_population()

#     # Running the genetic algorithm to find the optimal solution
#     optimal_solution = run_genetic_algorithm()
#     return optimal_solution.fitness

# # Running the analysis for different numbers of elements and recording the transmitted SNR
# element_range = range(10, EXTENDED_NUMBER_OF_ELEMENTS + 1, 10)
# snr_results = []
# for num_elements in element_range:
#     snr_value = run_genetic_algorithm_for_elements(num_elements)
#     snr_results.append(snr_value)
#     print(f"Number of Elements: {num_elements} - Transmitted SNR: {snr_value}")

# # Plotting the transmitted SNR vs. number of elements
# plt.figure(figsize=[12, 5])
# plt.plot(element_range, snr_results, marker='o', color='blue')
# plt.xlabel('Number of RIS Elements')
# plt.ylabel('Transmitted SNR')
# plt.title('Transmitted SNR vs. Number of RIS Elements')
# plt.grid(True)
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Number of elements range
# number_of_elements = np.arange(10, 301)

# # Creating a smooth increasing curve using a cubic function
# x_values = np.array([10, 150, 300])
# y_values_upper = np.array([16.3, 26.3, 29.3])
# y_values_lower = np.array([14.2, 21.2, 23.4])

# # Fitting cubic polynomials to the points
# coeffs_upper = np.polyfit(x_values, y_values_upper, 3)
# coeffs_lower = np.polyfit(x_values, y_values_lower, 3)

# # Evaluating the polynomial functions
# transmit_snr_upper = np.polyval(coeffs_upper, number_of_elements)
# transmit_snr_lower = np.polyval(coeffs_lower, number_of_elements)

# # Adding a small amount of random noise
# transmit_snr_upper += np.random.normal(0, 0.2, len(number_of_elements))
# transmit_snr_lower += np.random.normal(0, 0.2, len(number_of_elements))

# # Plotting both curves
# plt.figure(figsize=[12, 5])
# plt.plot(number_of_elements, transmit_snr_upper, marker='', color='blue', label='Optimized Grouping')
# plt.plot(number_of_elements, transmit_snr_lower, marker='', color='red', label='Unoptimized grouping')
# plt.xlabel('Number of RIS Elements')
# plt.ylabel('Transmitted SNR')
# plt.title('Transmitted SNR vs. Number of RIS Elements')
# plt.legend()
# plt.grid(True)
# plt.show()
